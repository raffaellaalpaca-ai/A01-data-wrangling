# %% [markdown]
# # Assignment: Data Wrangling

# %% [markdown]
# ### Reading material: `tidy_data.pdf`

# %% [markdown]
# **Q1.** This question provides some practice cleaning variables which have common problems.
# 1. For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. For the Minnesota police use of for data, `./data/mn_police_use_of_force.csv`, clean the `subject_injury` variable, handling the NA's; this gives a value `Yes` when a person was injured by police, and `No` when no injury occurred. What proportion of the values are missing? Is this a concern? Cross-tabulate your cleaned `subject_injury` variable with the `force_type` variable. Are there any patterns regarding when the data are missing?

# %% [markdown]
# **Q2.** Go to https://sharkattackfile.net/ and download their dataset on shark attacks (Hint: `GSAF5.xls`).
#
# 1. Open the shark attack file using Pandas. It is probably not a csv file, so `read_csv` won't work.
# 2. Drop any columns that do not contain data.
# 3. Clean the year variable. Describe the range of values you see. Filter the rows to focus on attacks since 1940. Are attacks increasing, decreasing, or remaining constant over time?
# 4. Clean the Age variable and make a histogram of the ages of the victims.
# 5. What proportion of victims are male?
# 6. Clean the `Type` variable so it only takes three values: Provoked and Unprovoked and Unknown. What proportion of attacks are unprovoked?

# %% [markdown]
# ---

# %% [markdown]
# ## *Phase 1: Solution without AI
#
# Complete all questions in the following cells without generative AI. Then commit and push the
# notebook before beginning Phase 2.

# %% [markdown]
# **Declaration:** I completed this version without generative AI.
#
# **Student(s):** Raffaella Alpaca
#
# **Date:** 09/02/2026

# %% [markdown]
# Question 1 - Part 1

# %%
# Your Phase 1 solution to the problem goes here.
import pandas as pd
import matplotlib.pyplot as plt
airbnb = pd.read_csv('https://raw.githubusercontent.com/sds3001/A01-data-wrangling/main/data/airbnb_hw.csv')

#shows first 5 rows to see the columns
airbnb.head()
#to show price column
airbnb['Price'].head()
# Out:
# 0    145
# 1     37
# 2     28
# 3    199
# 4    549
# Name: Price, dtype: object

# %%
#to inspect the bottom part
airbnb['Price'].tail()
# Out:
# 30473    300
# 30474    125
# 30475     80
# 30476     35
# 30477     80
# Name: Price, dtype: object

# %%
airbnb['Price'].dtype
# Out:
# dtype('O')

# %%
#looking for prices that have commas
airbnb[airbnb['Price'].str.contains(',')]
# Out:
#         Host Id Host Since                                 Name  \
# 101        8730  2/27/2009                Comfort & Convenience
# 263       34915  8/30/2009  Luxurious 2-Floor Manhattan Mansion
# 764      112879  4/23/2010  Modern Luxury Meets Old Money Charm
# 1272     214148  8/26/2010     LARGE, COMFY 1BDR W/CHARACTER!!!
# 1275     213266  8/26/2010   Beautiful 1 Bedroom in Nolita/Soho
# ...         ...        ...                                  ...
# 28951  37155810  6/30/2015         Central Park Luxury : 115916
# 28952  37155810  6/30/2015    Central Park South Place : 112756
# 28953  37155810  6/30/2015    Central Park South Views : 112754
# 28985  37241813   7/1/2015    VERY Spacious 3BR in East Village
# 30281  42160989  8/21/2015         Luxury Duplex for Pope Visit
#
#       Neighbourhood  Property Type  Review Scores Rating (bin)  \
# 101        Manhattan   Condominium                       100.0
# 263        Manhattan     Apartment                         NaN
# ...

# %%
#price values that are problematic
prices_w_commas = airbnb[airbnb['Price'].str.contains(',')]
prices_w_commas['Price'].head()
# Out:
# 101     1,990
# 263     1,000
# 764     1,200
# 1272    1,000
# 1275    5,000
# Name: Price, dtype: object

# %%
#removimg commas
airbnb['Price'] = airbnb['Price'].str.replace(',', '')
#checking again
airbnb['Price'].head()
# Out:
# 0    145
# 1     37
# 2     28
# 3    199
# 4    549
# Name: Price, dtype: object

# %%
airbnb['Price'].dtype
# Out:
# dtype('O')

# %%
#dtype is still an object
airbnb['Price'] = pd.to_numeric(airbnb['Price'])
airbnb['Price'].dtype
# Out:
# dtype('int64')

# %%
airbnb['Price'].head()
# Out:
# 0    145
# 1     37
# 2     28
# 3    199
# 4    549
# Name: Price, dtype: int64

# %% [markdown]
# Prices over 999 contained commas such as 1,000 or 1,990. This caused the price column to be stores as object instead of being a numeric type. I removed the commas and converted the column to numeric values

# %% [markdown]
# Question 2 - Part 2

# %%
#loading dataset

police = pd.read_csv('https://raw.githubusercontent.com/sds3001/A01-data-wrangling/main/data/mn_police_use_of_force.csv')

# %%
police.head()
# Out:
#      response_datetime               problem is_911_call primary_offense  \
# 0  2016/01/01 00:47:36  Assault in Progress          Yes          DASLT1
# 1  2016/01/01 02:19:34                Fight           No          DISCON
# 2  2016/01/01 02:19:34                Fight           No          DISCON
# 3  2016/01/01 02:28:48                Fight           No          PRIORI
# 4  2016/01/01 02:28:48                Fight           No          PRIORI
#
#   subject_injury         force_type   force_type_action   race     sex   age  \
# 0            NaN       Bodily Force  Body Weight to Pin  Black    Male  20.0
# 1            NaN  Chemical Irritant       Personal Mace  Black  Female  27.0
# 2            NaN  Chemical Irritant       Personal Mace  White  Female  23.0
# 3            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
# 4            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
#
#          type_resistance  precinct   neighborhood
# ...

# %%
police['subject_injury'].value_counts(dropna=False)
# Out:
# subject_injury
# NaN    9848
# Yes    1631
# No     1446
# Name: count, dtype: int64

# %%
#before deciding what to do with missing values, im gonna check if related to force_type
pd.crosstab(police['subject_injury'], police['force_type'])
# Out:
# force_type      Baton  Bodily Force  Chemical Irritant  Firearm  \
# subject_injury
# No                  0          1093                131        2
# Yes                 2          1286                 41        0
#
# force_type      Gun Point Display  Improvised Weapon  Less Lethal Projectile  \
# subject_injury
# No                             33                 34                       1
# Yes                            44                 40                       2
#
# force_type      Police K9 Bite  Taser
# subject_injury
# No                           2    150
# Yes                         44    172

# %%
#making a temp version for missing values
injury_check = police['subject_injury'].fillna('Missing')

# %%
pd.crosstab(injury_check, police['force_type'])
# Out:
# force_type      Baton  Bodily Force  Chemical Irritant  Firearm  \
# subject_injury
# Missing             2          7051               1421        0
# No                  0          1093                131        2
# Yes                 2          1286                 41        0
#
# force_type      Gun Point Display  Improvised Weapon  Less Lethal  \
# subject_injury
# Missing                        27                 74           87
# No                             33                 34            0
# Yes                            44                 40            0
#
# force_type      Less Lethal Projectile  Maximal Restraint Technique  \
# subject_injury
# Missing                              0                          170
# No                                   1                            0
# Yes                                  2                            0
#
# force_type      Police K9 Bite  Taser
# subject_injury
# Missing                     31    985
# ...

# %%
#calc the overall proportion of subject_injury that is missing
police['subject_injury'].isna().mean()
# Out:
# np.float64(0.7619342359767892)

# %% [markdown]
# Around 76% of the subject_injury values are missing. This is concerning because most of the data is not available , so its hard to make a promising conclusion about injuries.Also the missing values appear a lot for some force tyoes, so the missing data may not be fully random.

# %%
#cleaning column
police['injury_clean']= police['subject_injury']

# %%
police['injury_clean'].value_counts(dropna=False)
# Out:
# injury_clean
# NaN    9848
# Yes    1631
# No     1446
# Name: count, dtype: int64

# %% [markdown]
# The recorded subject_injury values were already labeled as yes and no. I decided to keeo the missing values as missing because it doesnt mean that no injuries occurred.

# %%
#cross tab using the clean column
pd.crosstab(police['injury_clean'], police['force_type'])
# Out:
# force_type    Baton  Bodily Force  Chemical Irritant  Firearm  \
# injury_clean
# No                0          1093                131        2
# Yes               2          1286                 41        0
#
# force_type    Gun Point Display  Improvised Weapon  Less Lethal Projectile  \
# injury_clean
# No                           33                 34                       1
# Yes                          44                 40                       2
#
# force_type    Police K9 Bite  Taser
# injury_clean
# No                         2    150
# Yes                       44    172

# %% [markdown]
# The cross tab shows that injuries are common for some tyoe force than others. Bodily force has many injury cases, while on the other hand, other force types have fewer.

# %% [markdown]
# Question 2

# %%
#reading the excel file
sharks = pd.read_excel('GSAF5.xls')

# %%
sharks.head()
# Out:
#            Date    Year        Type         Country                    State  \
# 0   26th August  2026.0  Unprovoked             USA                   Hawaii
# 1  23rd August   2026.0  Unprovoked             USA                  Florida
# 2   19th August  2026.0    Provoked  Reunion Island  Saint-Gilles-les-Baines
# 3   11th August  2026.0    Provoked         Ireland                Waterford
# 4    8th August  2026.0  Unprovoked             USA                    Maine
#
#                            Location                     Activity  \
# 0       Ala Moana Beach Park, Oah'u                      Surfing
# 1  Boca Grande (island in the keys)          Wading on a sandbar
# 2          Outer Reef Roches Noires                Spearfishiong
# 3                   Ardemore County                      Fishing
# 4            Scarborough Beach Park  Operation of Rescue Torpedo
#
#               Name Sex Age  ...                    Species   \
# ...

# %%
#load dataset and remove emoty columns
sharks.isna().all()
# Out:
# Date              False
# Year              False
# Type              False
# Country           False
# State             False
# Location          False
# Activity          False
# Name              False
# Sex               False
# Age               False
# Injury            False
# Fatal Y/N         False
# Time              False
# Species           False
# Source            False
# pdf               False
# href formula      False
# href              False
# Case Number       False
# Case Number.1     False
# original order    False
# Unnamed: 21       False
# Unnamed: 22       False
# dtype: bool

# %% [markdown]
# I checked for empty columns but none of the columns were fully empty

# %%
#cleaning the year column
sharks['Year'].head()
# Out:
# 0    2026.0
# 1    2026.0
# 2    2026.0
# 3    2026.0
# 4    2026.0
# Name: Year, dtype: float64

# %%
sharks['Year'].dtype
# Out:
# dtype('float64')

# %%
#to see if any weird missing values
sharks['Year'].value_counts(dropna=False)
# Out:
# Year
# 2015.0    143
# 2017.0    141
# 2016.0    133
# 0.0       129
# 2011.0    128
#          ...
# 1738.0      1
# 1500.0      1
# 1000.0      1
# 77.0        1
# 5.0         1
# Name: count, Length: 262, dtype: int64

# %%
#to keep only years
sharks = sharks[(sharks['Year'] >= 1800)& (sharks['Year'] <= 2026)]

# %%
#checking range
sharks['Year'].min()
# Out:
# 1800.0

# %%
sharks['Year'].max()
# Out:
# 2026.0

# %%
#trend over time
sharks['Year'].value_counts().sort_index()
# Out:
# Year
# 1800.0      1
# 1801.0      1
# 1802.0      1
# 1803.0      3
# 1804.0      1
#          ...
# 2022.0     98
# 2023.0    109
# 2024.0     52
# 2025.0     69
# 2026.0     53
# Name: count, Length: 216, dtype: int64

# %% [markdown]
# The number of recorded shark attacks generally increased over time. in the early 1800s there were only a few recorded attacks per year, while the most recent have more. The counts vary from year to year .

# %%
#age cleaning histogram
sharks['Age'].head()
# Out:
# 0     ?
# 1    43
# 2     ?
# 3    27
# 4    71
# Name: Age, dtype: object

# %%
sharks['Age'].dtype
# Out:
# dtype('O')

# %%
sharks['Age'].value_counts(dropna=False)
# Out:
# Age
# NaN            2834
# 16               91
# 17               89
# 19               89
# 17               86
#                ...
# ?    &   14       1
# 10 or 12          1
# 31 or 33          1
# 2½                1
# 1                 1
# Name: count, Length: 252, dtype: int64

# %%
#cleaning
sharks['Age_clean'] = pd.to_numeric(sharks['Age'], errors='coerce')
# Out:
# /tmp/ipykernel_2652/2081653499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks['Age_clean'] = pd.to_numeric(sharks['Age'], errors='coerce')

# %%
sharks['Age_clean'].head()
# Out:
# 0     NaN
# 1    43.0
# 2     NaN
# 3    27.0
# 4    71.0
# Name: Age_clean, dtype: float64

# %%
sharks['Age_clean'].dtype
# Out:
# dtype('float64')

# %%
#histogram
sharks['Age_clean'].hist()
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age of Shark Attack Victims')
plt.show()

# %% [markdown]
# i## *Phase 2: AI-assisted Revision
# Keep Phase 1 frozen.

# %% [markdown]
# - **Phase 1 commit SHA ID:** [To be provided]
# - **AI tool and model used:** [To be provided]

# %% [markdown]
# ### *Prompts used

# %% [markdown]
# 1. [Paste prompt]
# 2. [Paste follow-up prompt]

# %% [markdown]
# ### *AI-proposed changes

# %% [markdown]
# [Paste the AI's concise numbered list verbatim.]
#
# 1. ...
# 2. ...

# %% [markdown]
# ### *Evaluation of AI suggestions

# %% [markdown]
# | Change | Decision | Reason and verification |
# |---|---|---|
# | 1 | Accept / modify / reject | ... |
# | 2 | Accept / modify / reject | ... |

# %% [markdown]
# ### *AI-assisted solution in full
# After the evaluation of AI suggestions, incorporate the accepted revisions into your Phase 1 solution and provide the final Phase 2 solution in full in the following cells.

# %%
# Your Phase 2 solution to the problem goes here.

# %% [markdown]
# ### *Reflection on AI assistance
# In your own words without generative AI.

# %% [markdown]
# [In 150–300 words, describe the main improvements, AI mistakes or limitations, how the final solution was verified, and any remaining concerns.]
